# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
import xgboost as xgb

# %%
df=pd.read_excel('DS - Assignment Part 1 data set.xlsx')

# %%
df.head()
# Out:
#    Transaction date  House Age  Distance from nearest Metro station (km)  \
# 0       2012.916667       32.0                                  84.87882
# 1       2012.916667       19.5                                 306.59470
# 2       2013.583333       13.3                                 561.98450
# 3       2013.500000       13.3                                 561.98450
# 4       2012.833333        5.0                                 390.56840
#
#    Number of convenience stores  latitude  longitude  Number of bedrooms  \
# 0                            10  24.98298  121.54024                   1
# 1                             9  24.98034  121.53951                   2
# 2                             5  24.98746  121.54391                   3
# 3                             5  24.98746  121.54391                   2
# 4                             5  24.97937  121.54245                   1
#
#    House size (sqft)  House price of unit area
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 9 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Transaction date                          414 non-null    float64
#  1   House Age                                 414 non-null    float64
#  2   Distance from nearest Metro station (km)  414 non-null    float64
#  3   Number of convenience stores              414 non-null    int64
#  4   latitude                                  414 non-null    float64
#  5   longitude                                 414 non-null    float64
#  6   Number of bedrooms                        414 non-null    int64
#  7   House size (sqft)                         414 non-null    int64
#  8   House price of unit area                  414 non-null    float64
# dtypes: float64(6), int64(3)
# memory usage: 29.2 KB

# %%
df.drop('Transaction date',axis=1,inplace=True)

# %%
df['Net house price']=df['House size (sqft)']*df['House price of unit area']

# %%
# df.drop(['House size (sqft)','House price of unit area'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    House Age  Distance from nearest Metro station (km)  \
# 0       32.0                                  84.87882
# 1       19.5                                 306.59470
# 2       13.3                                 561.98450
# 3       13.3                                 561.98450
# 4        5.0                                 390.56840
#
#    Number of convenience stores  latitude  longitude  Number of bedrooms  \
# 0                            10  24.98298  121.54024                   1
# 1                             9  24.98034  121.53951                   2
# 2                             5  24.98746  121.54391                   3
# 3                             5  24.98746  121.54391                   2
# 4                             5  24.97937  121.54245                   1
#
#    House size (sqft)  House price of unit area  Net house price
# 0                575                      37.9          21792.5
# 1               1240                      42.2          52328.0
# ...

# %%
dataplot = sns.heatmap(df.corr(), cmap="YlGnBu", annot=True)

# %%
# ss=StandardScaler()
# x=ss.fit_transform(df[['House Age','Distance from nearest Metro station (km)','Number of convenience stores','Number of bedrooms']])
# y=ss.fit_transform(df[['Net house price']])

# %%
x=np.array(df[['House Age','Number of convenience stores','Number of bedrooms','House size (sqft)']])

# %%
y=np.array(df[['Net house price']])

# %%
len(x[0])
# Out:
# 4

# %%
len(y)
# Out:
# 414

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2)

# %%
clf = RandomForestRegressor(n_estimators=1000)

# %%
clf.fit(xtrain, ytrain)
# Out:
# C:\Users\JYOTI\AppData\Local\Temp\ipykernel_9984\3021215308.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(xtrain, ytrain)
# RandomForestRegressor(n_estimators=1000)

# %%
clf.score(xtest,ytest)
# Out:
# 0.7964423139141799

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
lr.score(xtest,ytest)
# Out:
# 0.7175822541265842

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor

# %%
regr_1 = DecisionTreeRegressor(max_depth=4)

regr_2 = AdaBoostRegressor(
    DecisionTreeRegressor(max_depth=20), n_estimators=1000
)

# %%
regr_1.fit(xtrain, ytrain)
regr_2.fit(xtrain, ytrain)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# AdaBoostRegressor(base_estimator=DecisionTreeRegressor(max_depth=20),
#                   n_estimators=1000)

# %%
regr_1.score(xtest,ytest)
# Out:
# 0.6764041683240262

# %%
regr_2.score(xtest,ytest)
# Out:
# 0.8193559284148048

# %%
import pickle
with open('scaler.pkl', 'wb') as file:
    pickle.dump(ss, file)

# %%
import pickle
with open('model.pkl','wb') as f:
    pickle.dump(regr_2,f)
